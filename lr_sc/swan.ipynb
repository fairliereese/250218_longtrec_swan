# %%
import swan_vis as swan 
import scanpy as sc
import pandas as pd
import anndata
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
sg = swan.read('../data/c2c12.p')
# Out:
# Read in graph from ../data/c2c12.p

# %% [markdown]
# ## Plot a few UMAPs

# %%
sc.pl.umap(sg.adata, color='leiden', frameon=False, size=120, show=False)
# Out:
# /Users/fairliereese/miniconda3/envs/swan/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# <Axes: title={'center': 'leiden'}, xlabel='UMAP1', ylabel='UMAP2'>

# %%
sc.pl.umap(sg.adata, color='celltype', frameon=False, size=120, show=False)
# Out:
# /Users/fairliereese/miniconda3/envs/swan/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# <Axes: title={'center': 'celltype'}, xlabel='UMAP1', ylabel='UMAP2'>

# %%
sg.adata.var = sg.adata.var.merge(sg.t_df, left_index=True, right_index=True)
sc.pl.umap(sg.adata, color='Tpm2-202', gene_symbols='tname', frameon=False, size=120, show=False)
# Out:
# <Axes: title={'center': 'Tpm2-202'}, xlabel='UMAP1', ylabel='UMAP2'>

# %%
sc.pl.umap(sg.tss_adata, color='Nisch_2', gene_symbols='tss_name', frameon=False, size=120, show=False, cmap='magma')
# Out:
# <Axes: title={'center': 'Nisch_2'}, xlabel='UMAP1', ylabel='UMAP2'>

# %% [markdown]
# ## Violin plots

# %%
print(sg.t_df.loc[sg.t_df.tname == 'Tpm2-202'])
sc.pl.violin(sg.adata, 'ENSMUST00000107913.9', groupby='leiden', jitter=0.4,
             size = 4, show = False, ylabel='Tpm2-202 Expression')
# Out:
#                          tname                 gid gname  \
# tid
# ENSMUST00000107913.9  Tpm2-202  ENSMUSG00000028464  Tpm2
#
#                                                                    path  \
# tid
# ENSMUST00000107913.9  [143855, 143834, 143835, 143836, 143837, 14383...
#
#                                        tid  \
# tid
# ENSMUST00000107913.9  ENSMUST00000107913.9
#
#                                                                loc_path  \
# tid
# ENSMUST00000107913.9  [697181, 697179, 697178, 697177, 697173, 69717...
#
#                       annotation novelty
# tid
# ENSMUST00000107913.9        True   Known
# <Axes: xlabel='leiden', ylabel='Tpm2-202 Expression'>

# %% [markdown]
# ## Swan report

# %%
_ = sg.gen_report('Tpm2', 
              prefix='figures/Tpm2', 
              cmap='viridis', 
#               display_numbers=True, 
              groupby='leiden',
              metadata_cols=['celltype', 'leiden'],
              indicate_novel=True, 
              transcript_col='tname',
#               browser=True,
              novelty=True)
# Out:
# Plotting transcripts for ENSMUSG00000028464
# Saving transcript path graph for ENSMUST00000107913.9 as figures/Tpm2_novel_ENSMUST00000107913.9_path.png
# Saving transcript path graph for ENCODEMT000193257 as figures/Tpm2_novel_ENCODEMT000193257_path.png
# Saving transcript path graph for ENCODEMT000193549 as figures/Tpm2_novel_ENCODEMT000193549_path.png
# Saving transcript path graph for ENSMUST00000107914.9 as figures/Tpm2_novel_ENSMUST00000107914.9_path.png
# Saving transcript path graph for ENSMUST00000030184.11 as figures/Tpm2_novel_ENSMUST00000030184.11_path.png
# Generating report for ENSMUSG00000028464

# %%
_ = sg.gen_report('Tnnt2', 
              prefix='figures/Tnnt2', 
              cmap='viridis', 
#               display_numbers=True, 
              groupby='leiden',
              metadata_cols=['celltype', 'leiden'],
              indicate_novel=True, 
              transcript_col='tname',
#               browser=True,
              novelty=True)
# Out:
# Plotting transcripts for ENSMUSG00000026414
# Saving transcript path graph for ENSMUST00000188098.1 as figures/Tnnt2_novel_ENSMUST00000188098.1_path.png
# Saving transcript path graph for ENCODEMT000413937 as figures/Tnnt2_novel_ENCODEMT000413937_path.png
# Saving transcript path graph for ENSMUST00000191055.1 as figures/Tnnt2_novel_ENSMUST00000191055.1_path.png
# Saving transcript path graph for ENCODEMT000413923 as figures/Tnnt2_novel_ENCODEMT000413923_path.png
# Saving transcript path graph for ENCODEMT000414631 as figures/Tnnt2_novel_ENCODEMT000414631_path.png
# Saving transcript path graph for ENCODEMT000414599 as figures/Tnnt2_novel_ENCODEMT000414599_path.png
# Saving transcript path graph for ENSMUST00000186225.1 as figures/Tnnt2_novel_ENSMUST00000186225.1_path.png
# Saving transcript path graph for ENCODEMT000414037 as figures/Tnnt2_novel_ENCODEMT000414037_path.png
# Generating report for ENSMUSG00000026414
